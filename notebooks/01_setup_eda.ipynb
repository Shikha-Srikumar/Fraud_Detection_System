# %% [markdown]
# #Imports and config

# %%
import os
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns

# %%
DATA_RAW = Path("../data/raw")
DATA_PROCESSED = Path("../data/processed")
DATA_RAW.mkdir(parents=True, exist_ok=True)
DATA_PROCESSED.mkdir(parents=True, exist_ok=True)

RANDOM_STATE = 42
pd.set_option("display.max_columns", 100)

# %% [markdown]
# #Loading full raw dataset

# %%
df = pd.read_csv("financial_fraud_detection_dataset.csv")
df.head()
# Out:
#   transaction_id                   timestamp sender_account receiver_account  \
# 0        T100000  2023-08-22T09:22:43.516168      ACC877572        ACC388389
# 1        T100001  2023-08-04T01:58:02.606711      ACC895667        ACC944962
# 2        T100002  2023-05-12T11:39:33.742963      ACC733052        ACC377370
# 3        T100003  2023-10-10T06:04:43.195112      ACC996865        ACC344098
# 4        T100004  2023-09-24T08:09:02.700162      ACC584714        ACC497887
#
#     amount transaction_type merchant_category location device_used  is_fraud  \
# 0   343.78       withdrawal         utilities    Tokyo      mobile     False
# 1   419.65       withdrawal            online  Toronto         atm     False
# 2  2773.86          deposit             other   London         pos     False
# 3  1666.22          deposit            online   Sydney         pos     False
# 4    24.43         transfer         utilities  Toronto      mobile     False
#
#   fraud_type  time_since_last_transaction  spending_deviation_score  \
# 0        NaN                          NaN                     -0.21
# 1        NaN                          NaN                     -0.14
# 2        NaN                          NaN                     -1.78
# 3        NaN                          NaN                     -0.60
# 4        NaN                          NaN                      0.79
#
#    velocity_score  geo_anomaly_score payment_channel       ip_address  \
# 0               3               0.22            card   13.101.214.112
# 1               7               0.96             ACH    172.52.47.194
# 2              20               0.89            card     185.98.35.23
# 3               6               0.37   wire_transfer    107.136.36.87
# 4              13               0.27             ACH  108.161.108.255
#
#   device_hash
# 0    D8536477
# 1    D2622631
# 2    D4823498
# 3    D9961380
# 4    D7637601

# %% [markdown]
# #Creating 10k chronological batches

# %%
BATCH_SIZE = 125000
BATCHES = 4
TOTAL_ROWS = BATCH_SIZE * BATCHES

df_sorted = df.sort_values("timestamp").reset_index(drop=True).iloc[:TOTAL_ROWS].copy()
print(df_sorted.shape)

# Save batches
names_3 = ["batch1_train.csv", "batch2_test.csv", "batch3_stream.csv"]
names_4 = names_3 + ["batch4_stream.csv"]
names = names_4 if BATCHES == 4 else names_3

start = 0
for i, name in enumerate(names, start=1):
    part = df_sorted.iloc[start:start+BATCH_SIZE].copy()
    part.to_csv(DATA_PROCESSED / name, index=False)
    print(name, part.shape, f"fraud_rate={part['is_fraud'].mean():.5f}")
    start += BATCH_SIZE
# Out:
# (500000, 18)
# batch1_train.csv (125000, 18) fraud_rate=0.03502
# batch2_test.csv (125000, 18) fraud_rate=0.03543
# batch3_stream.csv (125000, 18) fraud_rate=0.03590
# batch4_stream.csv (125000, 18) fraud_rate=0.03575

# %% [markdown]
# #Loading the working batches

# %%
train = pd.read_csv(DATA_PROCESSED / "batch1_train.csv")
test  = pd.read_csv(DATA_PROCESSED / "batch2_test.csv")
stream1 = pd.read_csv(DATA_PROCESSED / "batch3_stream.csv")
stream2 = None
if (DATA_PROCESSED / "batch4_stream.csv").exists():
    stream2 = pd.read_csv(DATA_PROCESSED / "batch4_stream.csv")

for name, part in [("train", train), ("test", test), ("stream1", stream1), ("stream2", stream2)]:
    if part is None: continue
    print(f"{name:7s} shape={part.shape}, fraud_rate={part['is_fraud'].mean():.5f}")
# Out:
# train   shape=(125000, 18), fraud_rate=0.03502
# test    shape=(125000, 18), fraud_rate=0.03543
# stream1 shape=(125000, 18), fraud_rate=0.03590
# stream2 shape=(125000, 18), fraud_rate=0.03575

# %% [markdown]
# #Dataset Overview

# %%
datasets = {
    "Train": train,
    "Test": test,
    "Stream1": stream1
}

if stream2 is not None:
    datasets["Stream2"] = stream2

summary = []

for name, data in datasets.items():

    fraud_rate = data["is_fraud"].mean() * 100

    summary.append({
        "Dataset": name,
        "Rows": len(data),
        "Columns": data.shape[1],
        "Fraud Cases": data["is_fraud"].sum(),
        "Fraud %": round(fraud_rate,4)
    })

summary = pd.DataFrame(summary)

display(summary)
# Out:
#    Dataset    Rows  Columns  Fraud Cases  Fraud %
# 0    Train  125000       18         4378   3.5024
# 1     Test  125000       18         4429   3.5432
# 2  Stream1  125000       18         4488   3.5904
# 3  Stream2  125000       18         4469   3.5752

# %% [markdown]
# #Missing Value Analysis

# %%
missing = train.isnull().sum()

missing = missing[missing > 0].sort_values(ascending=False)

display(missing)

plt.figure(figsize=(12,5))

sns.heatmap(train.isnull(),
            cbar=False,
            yticklabels=False)

plt.title("Missing Value Heatmap")

plt.show()
# Out:
# fraud_type                     120622
# time_since_last_transaction     22397
# dtype: int64

# %% [markdown]
# #Duplicate Records

# %%
duplicates = train.duplicated().sum()

print(f"Duplicate Rows : {duplicates}")
# Out:
# Duplicate Rows : 0

# %%
def summarize_split(df, label_col="is_fraud"):
    n = len(df)
    pos = df[label_col].sum()
    print(f"Rows={n}, Positives={int(pos)} ({pos/n:.4%})")

print("TRAIN"); summarize_split(train)
print("TEST"); summarize_split(test)
print("STREAM1"); summarize_split(stream1)
if stream2 is not None:
    print("STREAM2"); summarize_split(stream2)

# Amount & Time sanity
train[["amount","timestamp"]].describe()
# Out:
# TRAIN
# Rows=125000, Positives=4378 (3.5024%)
# TEST
# Rows=125000, Positives=4429 (3.5432%)
# STREAM1
# Rows=125000, Positives=4488 (3.5904%)
# STREAM2
# Rows=125000, Positives=4469 (3.5752%)
#               amount
# count  125000.000000
# mean      360.517163
# std       472.568531
# min         0.010000
# 25%        26.630000
# 50%       138.760000
# 75%       505.352500
# max      3038.670000

# %% [markdown]
# ****************************#Simple Visuals****************************

# %%
plt.figure(figsize=(6,5))

ax = sns.countplot(x="is_fraud",
                   data=train)

plt.title("Fraud vs Legitimate Transactions")

for p in ax.patches:

    ax.annotate(f"{int(p.get_height())}",

                (p.get_x()+0.3,

                 p.get_height()+20))

plt.show()

fraud_rate = train["is_fraud"].mean()*100

print(f"Fraud Percentage : {fraud_rate:.4f}%")
# Out:
# Fraud Percentage : 3.5024%

# %%
# 1) Imbalance bar
counts = train["is_fraud"].value_counts().sort_index()
plt.figure()
counts.plot(kind="bar")
plt.title("TRAIN: Class distribution (0=legit, 1=fraud)")
plt.xlabel("is_fraud"); plt.ylabel("Count")
plt.show()

# 2) Amount histogram (log1p to see tail)
#plt.figure()
#plt.hist(np.log1p(train["amount"]), bins=50)
#plt.title("TRAIN: log(amount+1) histogram")
#plt.xlabel("log(amount+1)"); plt.ylabel("Frequency")
#plt.show()

train["log_amount"] = np.log1p(train["amount"])

fig, axes = plt.subplots(1,2,figsize=(14,5))

axes[0].hist(train["amount"],bins=60)

axes[0].set_title("Original Amount")

axes[1].hist(train["log_amount"],bins=60)

axes[1].set_title("Log Transformed Amount")

plt.show()

# 3) Time vs Amount scatter (thin sample for speed)
sample = train.sample(min(3000, len(train)), random_state=RANDOM_STATE)
plt.figure()
plt.scatter(sample["timestamp"], np.log1p(sample["amount"]), alpha=0.3, s=10)
plt.title("TRAIN: Time vs log(amount+1)")
plt.xlabel("timestamp"); plt.ylabel("log(amount+1)")
plt.show()

# %%
fig, axes = plt.subplots(1,2,figsize=(12,5))

sns.boxplot(y=train["amount"],ax=axes[0])

axes[0].set_title("Amount")

sns.boxplot(y=train["log_amount"],ax=axes[1])

axes[1].set_title("Log Amount")

plt.show()

# %%
numeric_cols = [
    'amount',
    'time_since_last_transaction',
    'spending_deviation_score',
    'velocity_score',
    'geo_anomaly_score'
]

df[numeric_cols].boxplot(figsize=(10, 5))

plt.title('Box Plots of Numeric Features')
plt.xticks(rotation=90)
plt.show()

# %%
#print(train.dtypes)
dtype_summary = pd.DataFrame({

"Column":train.columns,

"Datatype":train.dtypes.astype(str)

})

display(dtype_summary)
# Out:
#                                                   Column Datatype
# transaction_id                            transaction_id      str
# timestamp                                      timestamp      str
# sender_account                            sender_account      str
# receiver_account                        receiver_account      str
# amount                                            amount  float64
# transaction_type                        transaction_type      str
# merchant_category                      merchant_category      str
# location                                        location      str
# device_used                                  device_used      str
# is_fraud                                        is_fraud     bool
# fraud_type                                    fraud_type      str
# time_since_last_transaction  time_since_last_transaction  float64
# spending_deviation_score        spending_deviation_score  float64
# velocity_score                            velocity_score    int64
# geo_anomaly_score                      geo_anomaly_score  float64
# payment_channel                          payment_channel      str
# ip_address                                    ip_address      str
# device_hash                                  device_hash      str
# log_amount                                    log_amount  float64

# %% [markdown]
# #Correlation Analysis

# %%
corr = train.corr(numeric_only=True)

plt.figure(figsize=(12,8))

sns.heatmap(corr,
            cmap="coolwarm",
            center=0)

plt.title("Correlation Matrix")

plt.show()

# %%
target_corr = (

train

.corr(numeric_only=True)["is_fraud"]

.sort_values(ascending=False)

)

display(target_corr)
# Out:
# is_fraud                       1.000000
# log_amount                     0.005511
# velocity_score                 0.001469
# amount                         0.000953
# spending_deviation_score       0.000441
# geo_anomaly_score             -0.000271
# time_since_last_transaction   -0.001889
# Name: is_fraud, dtype: float64

# %%
train["fraud_type"].value_counts(dropna=False)
# Out:
# fraud_type
# NaN                 120622
# card_not_present      4378
# Name: count, dtype: int64

# %%
pd.crosstab(train["fraud_type"], train["is_fraud"], dropna=False)
# Out:
# is_fraud           False  True
# fraud_type
# card_not_present       0   4378
# NaN               120622      0

# %%
# Save Clean Dataset

# %%
train.to_csv(

DATA_PROCESSED/"train_processed.csv",

index=False

)

test.to_csv(

DATA_PROCESSED/"test_processed.csv",

index=False

)

stream1.to_csv(

DATA_PROCESSED/"stream1_processed.csv",

index=False

)

if stream2 is not None:

    stream2.to_csv(

    DATA_PROCESSED/"stream2_processed.csv",

    index=False

)
